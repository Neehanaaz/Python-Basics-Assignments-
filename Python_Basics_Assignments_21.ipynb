# %% [markdown]
# 1. Add the current date to the text file today.txt as a string
#
#
# from datetime import date
#
# # get the current date as a string
# today = str(date.today())
#
# # open the file in append mode
# with open('today.txt', 'a') as file:
#     # write the date to the file
#     file.write(today + '\n')
# This code imports the date class from the datetime module to get the current date as a string. Then, it opens the file "today.txt" in append mode using a with block, which automatically closes the file when the block is exited.
#
# Within the with block, the code writes the current date to the file using the write() method. The '\n' character is added at the end of the string to write the date on a new line each time the code is run.
#
# 2. Read the text file today.txt into the string today_string
#
#
#
#
# # open the file in read mode
# with open('today.txt', 'r') as file:
#     # read the contents of the file into a string variable
#     today_string = file.read()
#
# # print the string to verify that it was read correctly
# print(today_string)
# This code opens the file "today.txt" in read mode using a with block, which automatically closes the file when the block is exited.
#
# Within the with block, the code reads the contents of the file into a string variable named today_string using the read() method.
#
# Finally, the code prints the string to verify that it was read correctly. You can modify this code to manipulate or analyze the contents of the file as needed.
#
#
#
# 3. Parse the date from today_string.3.
# To parse the date from the today_string variable, you first need to convert the string into a datetime object using the strptime() method, and then extract the date using the date() method.
#
# from datetime import datetime
#
# # convert the string to a datetime object
# dt_obj = datetime.strptime(today_string.strip(), '%Y-%m-%d')
#
# # extract the date from the datetime object
# date_obj = dt_obj.date()
#
# # print the date to verify that it was parsed correctly
# print(date_obj)
# This code uses the strptime() method from the datetime module to convert the today_string variable into a datetime object. The strip() method is used to remove any leading or trailing whitespace from the string.
#
# The second argument to strptime() is a string that specifies the format of the input string. In this case, the format is '%Y-%m-%d', which means that the string should be in the format 'YYYY-MM-DD'.
#
# Once the string has been converted to a datetime object, the code uses the date() method to extract the date as a separate date object.
#
# Finally, the code prints the date object to verify that it was parsed correctly.
#
#
#
#
# 4. List the files in your current directory
#
# import os
#
# # get the list of files in the current directory
# files = os.listdir()
#
# # print the list of files
# print("Files in current directory:")
# for file in files:
#     print(file)
# This code uses the os module to get the list of files in the current working directory using the listdir() method.
#
# The code then prints the list of files using a for loop, with each filename on a separate line. You can modify this code to perform operations on the files in the current directory, such as reading their contents or renaming them.
#
#
#
# 5. Create a list of all of the files in your parent directory (minimum five files should be available)
#
# import os
#
# # get the path to the parent directory
# parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
#
# # get the list of files in the parent directory
# files = os.listdir(parent_dir)
#
# # filter out directories and get only files
# files = [f for f in files if os.path.isfile(os.path.join(parent_dir, f))]
#
# # print the list of files
# print("Files in parent directory:")
# for file in files:
#     print(file)
# This code first uses the os module to get the absolute path of the parent directory of the current working directory. The abspath() method is used to get the absolute path, while the join() and pardir methods are used to traverse up to the parent directory.
#
# The code then uses the listdir() method to get the list of files in the parent directory.
#
# Since the listdir() method returns both files and directories, the code filters out directories using the isfile() method from the os module. The resulting list contains only the files in the parent directory.
#
# Finally, the code prints the list of files using a for loop. You can modify this code to perform operations on the files in the parent directory, such as reading their contents or renaming them.
#
#
#
#
# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.
#
# import multiprocessing
# import random
# import time
# from datetime import datetime
#
# def worker():
#     # wait for a random number of seconds between 1 and 5
#     wait_time = random.randint(1, 5)
#     time.sleep(wait_time)
#
#     # print the current time
#     current_time = datetime.now().strftime("%H:%M:%S")
#     print(f"Process {multiprocessing.current_process().name} waited {wait_time} seconds and printed at {current_time}")
#
# if __name__ == '__main__':
#     # create three separate processes
#     processes = []
#     for i in range(3):
#         p = multiprocessing.Process(target=worker, name=f"Process-{i}")
#         processes.append(p)
#         p.start()
#
#     # wait for all processes to finish
#     for p in processes:
#         p.join()
# This code defines a worker() function that is used as the target for the separate processes. The worker() function waits for a random number of seconds between 1 and 5 using the sleep() method from the time module.
#
# After waiting, the worker() function prints the current time using the strftime() method from the datetime module to format the time as a string.
#
# The main part of the code creates three separate processes using the Process() constructor from the multiprocessing module. Each process is given a unique name using the name parameter.
#
# The start() method is called on each process to start them running the worker() function.
#
# Finally, the code uses the join() method to wait for all processes to finish before exiting. The if __name__ == '__main__' clause is used to ensure that the multiprocessing code is only executed when the script is run as the main program, not when it is imported as a module.
#
#
#
#
# 7. Create a date object of your day of birth.
#
# Assuming your date of birth is represented as a string in the format "YYYY-MM-DD", you can use the strptime() method from the datetime module to parse the string and create a date object.
#
#
# from datetime import datetime, date
#
# # replace the string with your date of birth
# dob_str = "1990-05-15"
#
# # parse the string and create a date object
# dob = datetime.strptime(dob_str, "%Y-%m-%d").date()
#
# # print the date object
# print(dob)
# This code first imports the datetime and date classes from the datetime module.
#
# Next, the code defines a string variable dob_str that represents your date of birth. Replace this string with your actual date of birth in the format "YYYY-MM-DD".
#
# The strptime() method is then used to parse the dob_str string and create a datetime object. The date() method is called on the datetime object to extract only the date part and create a date object.
#
# Finally, the date object representing your date of birth is printed using the print() function.
#
#
#
#
# 8. What day of the week was your day of birth
# from datetime import datetime
#
# # replace the string with your date of birth
# dob_str = "1990-05-15"
#
# # parse the string and create a datetime object
# dob = datetime.strptime(dob_str, "%Y-%m-%d")
#
# # determine the day of the week as an integer (Monday = 0, Sunday = 6)
# day_of_week = dob.weekday()
#
# # convert the integer to a string representing the day of the week
# days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# day_of_week_str = days_of_week[day_of_week]
#
# # print the day of the week
# print(day_of_week_str)
# This code first imports the datetime class from the datetime module.
#
# Next, the code defines a string variable dob_str that represents your date of birth. Replace this string with your actual date of birth in the format "YYYY-MM-DD".
#
# The strptime() method is then used to parse the dob_str string and create a datetime object.
#
# The weekday() method is called on the datetime object to determine the day of the week as an integer, where Monday is represented by 0 and Sunday is represented by 6.
#
# The code then creates a list of strings representing the days of the week and uses the integer returned by weekday() to extract the appropriate string.
#
# Finally, the string representing the day of the week is printed using the print() function.
#
#
# 9. When will you be (or when were you) 10,000 days old?
#
#
# from datetime import datetime, timedelta
#
# # replace the string with your date of birth
# dob_str = "1990-05-15"
#
# # parse the string and create a datetime object
# dob = datetime.strptime(dob_str, "%Y-%m-%d")
#
# # calculate the date when you will be or were 10,000 days old
# ten_thousand_days = timedelta(days=10000)
# ten_thousand_days_date = dob + ten_thousand_days
#
# # print the date when you will be or were 10,000 days old
# print(ten_thousand_days_date.date())
# This code first imports the datetime and timedelta classes from the datetime module.
#
# Next, the code defines a string variable dob_str that represents your date of birth. Replace this string with your actual date of birth in the format "YYYY-MM-DD".
#
# The strptime() method is then used to parse the dob_str string and create a datetime object.
#
# The timedelta() function is used to create a timedelta object representing 10,000 days.
#
# The + operator is used to add the timedelta object to the datetime object representing your date of birth, resulting in a new datetime object representing the date when you will be or were 10,000 days old.
#
# Finally, the date when you will be or were 10,000 days old is printed using the print() function.
