# %% [markdown]
# 1. Make a class called Thing with no contents and print it. Then, create an object called example from this class and also print it. Are the printed values the same or different?
# Here's an example code to create a class called Thing with no contents and print it:
#
#
# class Thing:
#     pass
#
# print(Thing)
# This will output <class '__main__.Thing'>, indicating that we have created a class called Thing.
#
# To create an object called example from this class and print it, we can do the following:
#
# example = Thing()
# print(example)
# This will output something like <__main__.Thing object at 0x7f5f466862e0>, which indicates that we have created an instance of the Thing class.
#
# The printed values for the class Thing and the object example are different, as expected. The class Thing is just a blueprint for creating objects, whereas the object example is an instance of the class.
#
#
# 2. Create a new class called Thing2 and add the value 'abc' to the letters class attribute. Letters should be printed.
# Here's an example code to create a new class called Thing2 and add the value 'abc' to the letters class attribute, then print the value of letters:
#
#
# class Thing2:
#     letters = 'abc'
#
# print(Thing2.letters)
# This will output abc, which is the value of the letters class attribute that we defined in the Thing2 class. Note that we accessed the letters attribute using the class name Thing2, rather than an instance of the class. This is because letters is a class attribute, not an instance attribute.
#
#
#
#
#
# 3. Make yet another class called, of course, Thing3. This time, assign the value 'xyz' to an instance (object) attribute called letters. Print letters. Do you need to make an object from the class to do this?
# Here's an example code to create a class called Thing3, assign the value 'xyz' to an instance attribute called letters, and print the value of letters:
#
# class Thing3:
#     def __init__(self):
#         self.letters = 'xyz'
#
# example = Thing3()
# print(example.letters)
# In this code, we created a class Thing3 and defined an instance attribute letters in its constructor using the self keyword. We then created an object example from the Thing3 class, which initializes the instance attribute letters to 'xyz'. Finally, we printed the value of letters for the example object.
#
# Yes, we need to create an object from the Thing3 class to access its instance attribute letters, since this attribute belongs to instances of the class, not the class itself.
#
#
#
#
# 4. Create an Element class with the instance attributes name, symbol, and number. Create a class object with the values 'Hydrogen,' 'H,' and 1.
# Here's an example code to create an Element class with instance attributes name, symbol, and number, and then create an object hydrogen from this class with the values 'Hydrogen', 'H', and 1:
#
#
# class Element:
#     def __init__(self, name, symbol, number):
#         self.name = name
#         self.symbol = symbol
#         self.number = number
#
# hydrogen = Element('Hydrogen', 'H', 1)
# In this code, we defined an Element class with an __init__ method that takes three arguments name, symbol, and number, and initializes the corresponding instance attributes with these values using the self keyword. Then we created an object hydrogen from the Element class with the values 'Hydrogen', 'H', and 1 by passing these values as arguments to the constructor.
#
#
#
#
# 5. Make a dictionary with these keys and values: 'name': 'Hydrogen', 'symbol': 'H', 'number': 1. Then, create an object called hydrogen from class Element using this dictionary.
# Here's an example code to create a dictionary with keys and values 'name': 'Hydrogen', 'symbol': 'H', and 'number': 1, and then create an object hydrogen from the Element class using this dictionary:
#
#
# element_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
#
# hydrogen = Element(**element_dict)
# In this code, we created a dictionary element_dict with keys 'name', 'symbol', and 'number', and corresponding values 'Hydrogen', 'H', and 1, respectively. We then created an object hydrogen from the Element class using the ** syntax to pass the key-value pairs in the dictionary as arguments to the constructor. This is equivalent to calling Element(name='Hydrogen', symbol='H', number=1).
#
#
#
#
# 6. For the Element class, define a method called dump() that prints the values of the object’s attributes (name, symbol, and number). Create the hydrogen object from this new definition and use dump() to print its attributes.
# Here's an example code to define a dump() method in the Element class that prints the values of the object's attributes, and then create an object hydrogen from this class and use the dump() method to print its attributes:
#
# class Element:
#     def __init__(self, name, symbol, number):
#         self.name = name
#         self.symbol = symbol
#         self.number = number
#
#     def dump(self):
#         print(f"Name: {self.name}, Symbol: {self.symbol}, Number: {self.number}")
#
# hydrogen = Element('Hydrogen', 'H', 1)
# hydrogen.dump()
# In this code, we defined an Element class with an __init__ method that takes three arguments name, symbol, and number, and initializes the corresponding instance attributes with these values using the self keyword. We also defined a dump() method in the Element class that prints the values of the object's attributes using string formatting. Then we created an object hydrogen from the Element class with the values 'Hydrogen', 'H', and 1 by passing these values as arguments to the constructor. Finally, we called the dump() method on the hydrogen object to print its attributes.
#
#
#
# 7. Call print(hydrogen). In the definition of Element, change the name of method dump to __str__, create a new hydrogen object, and call print(hydrogen) again.
# Here's an example code to call print(hydrogen) before and after changing the name of the dump() method in the Element class to __str__():
#
#
# class Element:
#     def __init__(self, name, symbol, number):
#         self.name = name
#         self.symbol = symbol
#         self.number = number
#
#     def __str__(self):
#         return f"Name: {self.name}, Symbol: {self.symbol}, Number: {self.number}"
#
# hydrogen = Element('Hydrogen', 'H', 1)
#
# print(hydrogen)
#
# # Output:
# # Name: Hydrogen, Symbol: H, Number: 1
#
# In this code, we defined an Element class with an __init__ method that takes three arguments name, symbol, and number, and initializes the corresponding instance attributes with these values using the self keyword. We also changed the name of the dump() method to __str__(), which is a special method in Python that gets called when an object is converted to a string using the str() function or the print() function. The __str__() method returns a formatted string representing the object's attributes. Then we created an object hydrogen from the Element class with the values 'Hydrogen', 'H', and 1 by passing these values as arguments to the constructor. Finally, we called print(hydrogen) to print the hydrogen object, which calls the __str__() method to convert the object to a string and print it. The output shows the formatted string representing the hydrogen object's attributes.
#
#
#
#
#
# 8. Modify Element to make the attributes name, symbol, and number private. Define a getter property for each to return its value.
# Here's an example code to modify the Element class to make the name, symbol, and number attributes private and define a getter property for each attribute to return its value:
#
#
# class Element:
#     def __init__(self, name, symbol, number):
#         self._name = name
#         self._symbol = symbol
#         self._number = number
#
#     @property
#     def name(self):
#         return self._name
#
#     @property
#     def symbol(self):
#         return self._symbol
#
#     @property
#     def number(self):
#         return self._number
#
# hydrogen = Element('Hydrogen', 'H', 1)
#
# print(hydrogen.name)    # Output: Hydrogen
# print(hydrogen.symbol)  # Output: H
# print(hydrogen.number)  # Output: 1
# In this code, we modified the __init__ method of the Element class to initialize the _name, _symbol, and _number attributes instead of name, symbol, and number. By convention, a single leading underscore before a variable name in Python indicates that the variable is intended to be private, although it is still accessible outside of the class.
#
# We defined a getter property for each attribute using the @property decorator. Each getter method simply returns the value of the corresponding private attribute.
#
# Finally, we created an object hydrogen from the modified Element class and accessed its attributes using the getter properties. The output shows the values of the name, symbol, and number attributes, which are now accessed through the getter methods.
#
#
#
#
# 9. Define three classes: Bear, Rabbit, and Octothorpe. For each, define only one method: eats(). This should return 'berries' (Bear), 'clover' (Rabbit), or 'campers' (Octothorpe). Create one object from each and print what it eats.
# Here's an example code to define the Bear, Rabbit, and Octothorpe classes with the eats() method and create one object from each class to print what it eats:
# class Bear:
#     def eats(self):
#         return 'berries'
#
# class Rabbit:
#     def eats(self):
#         return 'clover'
#
# class Octothorpe:
#     def eats(self):
#         return 'campers'
#
# bear = Bear()
# rabbit = Rabbit()
# octothorpe = Octothorpe()
#
# print("The bear eats", bear.eats())           # Output: The bear eats berries
# print("The rabbit eats", rabbit.eats())       # Output: The rabbit eats clover
# print("The octothorpe eats", octothorpe.eats()) # Output: The octothorpe eats campers
# In this code, we defined the Bear, Rabbit, and Octothorpe classes, each with a single eats() method that returns the food that the corresponding animal eats. We then created an object bear from the Bear class, rabbit from the Rabbit class, and octothorpe from the Octothorpe class. Finally, we printed what each animal eats by calling its eats() method and concatenating the result with a string using the + operator. The output shows what each animal eats according to its eats() method.
#
#
#
#
#
# 10. Define these classes: Laser, Claw, and SmartPhone. Each has only one method: does(). This returns 'disintegrate' (Laser), 'crush' (Claw), or 'ring' (SmartPhone). Then, define the class Robot that has one instance (object) of each of these. Define a does() method for the Robot that prints what its component objects do.
# Here's an example code to define the Laser, Claw, and SmartPhone classes, each with a does() method that returns a string describing what it does. Then we define the Robot class with an instance of each component class and a does() method that prints what each component does:
#
#
# class Laser:
#     def does(self):
#         return 'disintegrate'
#
# class Claw:
#     def does(self):
#         return 'crush'
#
# class SmartPhone:
#     def does(self):
#         return 'ring'
#
# class Robot:
#     def __init__(self):
#         self.laser = Laser()
#         self.claw = Claw()
#         self.phone = SmartPhone()
#
#     def does(self):
#         print('The robot does the following:')
#         print('- Laser:', self.laser.does())
#         print('- Claw:', self.claw.does())
#         print('- Phone:', self.phone.does())
#
# robot = Robot()
# robot.does()
# In this code, we defined the Laser, Claw, and SmartPhone classes, each with a single does() method that returns a string describing what the object does. We then defined the Robot class, which has an instance of each of the three component classes (Laser, Claw, and SmartPhone) as instance attributes. The Robot class also has a does() method that prints what each component does by calling its does() method. Finally, we created a Robot object and called its does() method to see what it does. The output shows what each component of the robot does.
